# %% [markdown]
# ### Data Ingestion

# %%
### document datastructure
from langchain_core.documents import Document

# %%
# !uv pip list
# Out:
# Package                 Version
# ----------------------- -----------
# annotated-types         0.7.0
# anyio                   4.13.0
# asttokens               3.0.1
# certifi                 2026.4.22
# charset-normalizer      3.4.7
# colorama                0.4.6
# comm                    0.2.3
# debugpy                 1.8.20
# decorator               5.2.1
# executing               2.2.1
# h11                     0.16.0
# httpcore                1.0.9
# httpx                   0.28.1
# idna                    3.13
# ipykernel               7.2.0
# ipython                 9.13.0
# ipython-pygments-lexers 1.1.1
# jedi                    0.19.2
# jsonpatch               1.33
# jsonpointer             3.1.1
# jupyter-client          8.8.0
# jupyter-core            5.9.1
# langchain               1.2.15
# langchain-core          1.3.2
# langchain-protocol      0.0.12
# langgraph               1.1.10
# langgraph-checkpoint    4.0.3
# langgraph-prebuilt      1.0.12
# langgraph-sdk           0.3.13
# langsmith               0.7.37
# matplotlib-inline       0.2.1
# mkl-fft                 2.2.0
# mkl-random              1.3.0
# mkl-service             2.5.2
# nest-asyncio            1.6.0
# numpy                   2.4.4
# orjson                  3.11.8
# ormsgpack               1.12.2
# packaging               26.0
# pandas                  3.0.2
# parso                   0.8.6
# pip                     26.0.1
# platformdirs            4.9.6
# prompt-toolkit          3.0.52
# psutil                  7.2.2
# pure-eval               0.2.3
# pydantic                2.13.3
# pydantic-core           2.46.3
# pygments                2.20.0
# python-dateutil         2.9.0.post0
# pyyaml                  6.0.3
# pyzmq                   27.1.0
# requests                2.33.1
# requests-toolbelt       1.0.0
# setuptools              82.0.1
# six                     1.17.0
# stack-data              0.6.3
# tenacity                9.1.4
# tornado                 6.5.5
# traitlets               5.14.3
# typing-extensions       4.15.0
# typing-inspection       0.4.2
# tzdata                  2025.3
# urllib3                 2.6.3
# uuid-utils              0.14.1
# wcwidth                 0.6.0
# wheel                   0.46.3
# xxhash                  3.7.0
# zstandard               0.25.0
# Using Python 3.12.0 environment at: C:\Users\Win11\OneDrive\PythonCrashCourse\venv

# %%
doc=Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"example.txt",
        "pages":1,
        "auther":"Atul",
        "datecreated":"2026-09-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'auther': 'Atul', 'datecreated': '2026-09-01'}, page_content='this is the main text content I am using to create RAG')

# %%
type(doc)
# Out:
# langchain_core.documents.base.Document

# %%
## create a txt file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
### TextLoader
from langchain_community.document_loaders import TextLoader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 2
#       1 ### TextLoader
# ----> 2 from langchain_community.document_loaders import TextLoader
#
# ModuleNotFoundError: No module named 'langchain_community'
